# %%
#Import required libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import datasets
data1=pd.read_csv("ipl/IPL_Ball_by_Ball_2008_2022.csv")
ball=data1.copy()
ball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
data2=pd.read_csv("ipl/IPL_Matches_2008_2022.csv")
matches=data2.copy()
matches.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
#Data Cleaning / Data Manipulation

# %%
#Manipulating "Season" by replacing years
matches["Season"]=matches["Season"].replace(["2007/08","2009/10","2020/21"],["2008","2010","2020"])

# %%
#Find unique teams in dataset
team=pd.concat([matches['Team1'], matches['Team2']])
teams=set(team)

# %%
teams
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
#Since some teams have changed their team names , replaced with only one name
teams_rename={"Delhi Daredevils":"Delhi Capitals",'Rising Pune Supergiants':'Rising Pune Supergiant','Kings XI Punjab':"Punjab Kings","Pune Warriors":"Rising Pune Supergiant"}

# %%
matches.replace({"Team1": teams_rename, "Team2": teams_rename,"WinningTeam":teams_rename}, inplace=True)

# %%
team1=pd.concat([matches['Team1'], matches['Team2']])
new_teams=set(team1)

# %%
new_teams
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
#Renaming teams in "ball" dataset.
ball.replace({"BattingTeam": teams_rename}, inplace=True)

# %%
#Calculate total_runs of each team in each match based on ID
total_runs = ball.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_runs
# Out:
#            ID  innings  total_run
# 0      335982        1        222
# 1      335982        2         82
# 2      335983        1        240
# 3      335983        2        207
# 4      335984        1        129
# ...       ...      ...        ...
# 1923  1312198        2        193
# 1924  1312199        1        157
# 1925  1312199        2        161
# 1926  1312200        1        130
# 1927  1312200        2        133
#
# [1928 rows x 3 columns]

# %%
#Calculate target for teams that has to be played in "Innings"==2
for ID in total_runs['ID'].unique():
    # Filter DataFrame for innings 1
    inning_1 = total_runs[(total_runs['ID'] == ID) & (total_runs['innings'] == 1)]
    # Calculate target for innings 2
    target_for_innings_2 = inning_1['total_run'].iloc[0] + 1
    # Update target for innings 2 in the DataFrame
    total_runs.loc[(total_runs['ID'] == ID) & (total_runs['innings'] == 2), 'target'] = target_for_innings_2

print(total_runs)
# Out:
#            ID  innings  total_run  target
# 0      335982        1        222     NaN
# 1      335982        2         82   223.0
# 2      335983        1        240     NaN
# 3      335983        2        207   241.0
# 4      335984        1        129     NaN
# ...       ...      ...        ...     ...
# 1923  1312198        2        193   208.0
# 1924  1312199        1        157     NaN
# 1925  1312199        2        161   158.0
# 1926  1312200        1        130     NaN
# 1927  1312200        2        133   131.0
#
# [1928 rows x 4 columns]

# %%
#Since the Innings==1 doesn't have any target , filled with "0"
total_runs["target"]=total_runs["target"].fillna(0)

# %%
total_runs
# Out:
#            ID  innings  total_run  target
# 0      335982        1        222     0.0
# 1      335982        2         82   223.0
# 2      335983        1        240     0.0
# 3      335983        2        207   241.0
# 4      335984        1        129     0.0
# ...       ...      ...        ...     ...
# 1923  1312198        2        193   208.0
# 1924  1312199        1        157     0.0
# 1925  1312199        2        161   158.0
# 1926  1312200        1        130     0.0
# 1927  1312200        2        133   131.0
#
# [1928 rows x 4 columns]

# %%
#total_runs = total_runs[total_runs['innings']==2]

# %%
#total_runs

# %%
#Merging datasets "matches" and "total_runs" on "ID"

# %%
match_df = matches.merge(total_runs[['ID','total_run','target']],on="ID")

# %%
match_df
# Out:
#            ID        City        Date Season  MatchNumber  \
# 0     1312200   Ahmedabad  2022-05-29   2022        Final
# 1     1312200   Ahmedabad  2022-05-29   2022        Final
# 2     1312199   Ahmedabad  2022-05-27   2022  Qualifier 2
# 3     1312199   Ahmedabad  2022-05-27   2022  Qualifier 2
# 4     1312198     Kolkata  2022-05-25   2022   Eliminator
# ...       ...         ...         ...    ...          ...
# 1923   335984       Delhi  2008-04-19   2008            3
# 1924   335983  Chandigarh  2008-04-19   2008            2
# 1925   335983  Chandigarh  2008-04-19   2008            2
# 1926   335982   Bangalore  2008-04-18   2008            1
# 1927   335982   Bangalore  2008-04-18   2008            1
#
#                             Team1                  Team2  \
# 0                Rajasthan Royals         Gujarat Titans
# 1                Rajasthan Royals         Gujarat Titans
# 2     Royal Challengers Bangalore       Rajasthan Royals
# 3     Royal Challengers Bangalore       Rajasthan Royals
# 4     Royal Challengers Bangalore   Lucknow Super Giants
# ...                           ...                    ...
# 1923               Delhi Capitals       Rajasthan Royals
# 1924                 Punjab Kings    Chennai Super Kings
# 1925                 Punjab Kings    Chennai Super Kings
# 1926  Royal Challengers Bangalore  Kolkata Knight Riders
# 1927  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                            Venue                   TossWinner  \
# 0               Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1               Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2               Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 3               Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 4                          Eden Gardens, Kolkata         Lucknow Super Giants
# ...                                          ...                          ...
# 1923                            Feroz Shah Kotla             Rajasthan Royals
# 1924  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 1925  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 1926                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1927                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#      TossDecision  ...    WonBy Margin method  Player_of_Match  \
# 0             bat  ...  Wickets    7.0    NaN        HH Pandya
# 1             bat  ...  Wickets    7.0    NaN        HH Pandya
# 2           field  ...  Wickets    7.0    NaN       JC Buttler
# 3           field  ...  Wickets    7.0    NaN       JC Buttler
# 4           field  ...     Runs   14.0    NaN       RM Patidar
# ...           ...  ...      ...    ...    ...              ...
# 1923          bat  ...  Wickets    9.0    NaN      MF Maharoof
# 1924          bat  ...     Runs   33.0    NaN       MEK Hussey
# 1925          bat  ...     Runs   33.0    NaN       MEK Hussey
# 1926        field  ...     Runs  140.0    NaN      BB McCullum
# 1927        field  ...     Runs  140.0    NaN      BB McCullum
#
#                                            Team1Players  \
# 0     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 2     ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3     ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 4     ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# ...                                                 ...
# 1923  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 1924  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 1925  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 1926  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 1927  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                            Team2Players        Umpire1  \
# 0     ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1     ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 2     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 3     ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 4     ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# ...                                                 ...            ...
# 1923  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 1924  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 1925  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 1926  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
# 1927  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#              Umpire2 total_run target
# 0        Nitin Menon       130    0.0
# 1        Nitin Menon       133  131.0
# 2        Nitin Menon       157    0.0
# 3        Nitin Menon       161  158.0
# 4           MA Gough       207    0.0
# ...              ...       ...    ...
# 1923  GA Pratapkumar       132  130.0
# 1924      SL Shastri       240    0.0
# 1925      SL Shastri       207  241.0
# 1926     RE Koertzen       222    0.0
# 1927     RE Koertzen        82  223.0
#
# [1928 rows x 22 columns]

# %%
match_df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'total_run', 'target'],
#       dtype='object')

# %%
#Create a dataframe frame from "match_df" having only required columns.
match_df=match_df[['ID', 'City','Season', 'MatchNumber', 'Team1', 'Team2','WinningTeam','Player_of_Match','Team1Players',
       'Team2Players','total_run', 'target']]

# %%
#Merge match_df dataset with ball dataset
match_df2= match_df.merge(ball,on='ID')
match_df2
# Out:
#              ID       City Season MatchNumber                        Team1  \
# 0       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 1       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 2       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 3       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 4       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# ...         ...        ...    ...         ...                          ...
# 459518   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459519   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459520   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459521   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459522   335982  Bangalore   2008           1  Royal Challengers Bangalore
#
#                         Team2            WinningTeam Player_of_Match  \
# 0              Gujarat Titans         Gujarat Titans       HH Pandya
# 1              Gujarat Titans         Gujarat Titans       HH Pandya
# 2              Gujarat Titans         Gujarat Titans       HH Pandya
# 3              Gujarat Titans         Gujarat Titans       HH Pandya
# 4              Gujarat Titans         Gujarat Titans       HH Pandya
# ...                       ...                    ...             ...
# 459518  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459519  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459520  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459521  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459522  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
#
#                                              Team1Players  \
# 0       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 2       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 3       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# ...                                                   ...
# 459518  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459519  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459520  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459521  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459522  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                              Team2Players  ...  extra_type  \
# 0       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...         NaN
# 1       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...     legbyes
# 2       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...         NaN
# 3       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...         NaN
# 4       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...         NaN
# ...                                                   ...  ...         ...
# 459518  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...     legbyes
# 459519  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...         NaN
# 459520  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...         NaN
# 459521  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...       wides
# 459522  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...         NaN
#
#         batsman_run  extras_run  total_run_y  non_boundary isWicketDelivery  \
# 0                 0           0            0             0                0
# 1                 0           1            1             0                0
# 2                 1           0            1             0                0
# 3                 0           0            0             0                0
# 4                 0           0            0             0                0
# ...             ...         ...          ...           ...              ...
# 459518            0           1            1             0                0
# 459519            1           0            1             0                0
# 459520            0           0            0             0                0
# 459521            0           1            1             0                0
# 459522            0           0            0             0                1
#
#        player_out    kind fielders_involved                  BattingTeam
# 0             NaN     NaN               NaN             Rajasthan Royals
# 1             NaN     NaN               NaN             Rajasthan Royals
# 2             NaN     NaN               NaN             Rajasthan Royals
# 3             NaN     NaN               NaN             Rajasthan Royals
# 4             NaN     NaN               NaN             Rajasthan Royals
# ...           ...     ...               ...                          ...
# 459518        NaN     NaN               NaN  Royal Challengers Bangalore
# 459519        NaN     NaN               NaN  Royal Challengers Bangalore
# 459520        NaN     NaN               NaN  Royal Challengers Bangalore
# 459521        NaN     NaN               NaN  Royal Challengers Bangalore
# 459522   SB Joshi  caught       BB McCullum  Royal Challengers Bangalore
#
# [459523 rows x 28 columns]

# %%
#Define a function to add bowling team
def bowling_team(team):
    if team["BattingTeam"]==team["Team1"]:
        return team["Team2"]
    else:
        return team["Team1"]

# %%
#Adding column "bowling team" to "match_df2"
match_df2["BowlingTeam"]=match_df2.apply(bowling_team,axis=1)

# %%
match_df2
# Out:
#              ID       City Season MatchNumber                        Team1  \
# 0       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 1       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 2       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 3       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# 4       1312200  Ahmedabad   2022       Final             Rajasthan Royals
# ...         ...        ...    ...         ...                          ...
# 459518   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459519   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459520   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459521   335982  Bangalore   2008           1  Royal Challengers Bangalore
# 459522   335982  Bangalore   2008           1  Royal Challengers Bangalore
#
#                         Team2            WinningTeam Player_of_Match  \
# 0              Gujarat Titans         Gujarat Titans       HH Pandya
# 1              Gujarat Titans         Gujarat Titans       HH Pandya
# 2              Gujarat Titans         Gujarat Titans       HH Pandya
# 3              Gujarat Titans         Gujarat Titans       HH Pandya
# 4              Gujarat Titans         Gujarat Titans       HH Pandya
# ...                       ...                    ...             ...
# 459518  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459519  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459520  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459521  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
# 459522  Kolkata Knight Riders  Kolkata Knight Riders     BB McCullum
#
#                                              Team1Players  \
# 0       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 2       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 3       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4       ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# ...                                                   ...
# 459518  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459519  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459520  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459521  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 459522  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                              Team2Players  ...  batsman_run  \
# 0       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...            0
# 1       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...            0
# 2       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...            1
# 3       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...            0
# 4       ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  ...            0
# ...                                                   ...  ...          ...
# 459518  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...            0
# 459519  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...            1
# 459520  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...            0
# 459521  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...            0
# 459522  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  ...            0
#
#         extras_run  total_run_y  non_boundary  isWicketDelivery player_out  \
# 0                0            0             0                 0        NaN
# 1                1            1             0                 0        NaN
# 2                0            1             0                 0        NaN
# 3                0            0             0                 0        NaN
# 4                0            0             0                 0        NaN
# ...            ...          ...           ...               ...        ...
# 459518           1            1             0                 0        NaN
# 459519           0            1             0                 0        NaN
# 459520           0            0             0                 0        NaN
# 459521           1            1             0                 0        NaN
# 459522           0            0             0                 1   SB Joshi
#
#           kind fielders_involved                  BattingTeam  \
# 0          NaN               NaN             Rajasthan Royals
# 1          NaN               NaN             Rajasthan Royals
# 2          NaN               NaN             Rajasthan Royals
# 3          NaN               NaN             Rajasthan Royals
# 4          NaN               NaN             Rajasthan Royals
# ...        ...               ...                          ...
# 459518     NaN               NaN  Royal Challengers Bangalore
# 459519     NaN               NaN  Royal Challengers Bangalore
# 459520     NaN               NaN  Royal Challengers Bangalore
# 459521     NaN               NaN  Royal Challengers Bangalore
# 459522  caught       BB McCullum  Royal Challengers Bangalore
#
#                   BowlingTeam
# 0              Gujarat Titans
# 1              Gujarat Titans
# 2              Gujarat Titans
# 3              Gujarat Titans
# 4              Gujarat Titans
# ...                       ...
# 459518  Kolkata Knight Riders
# 459519  Kolkata Knight Riders
# 459520  Kolkata Knight Riders
# 459521  Kolkata Knight Riders
# 459522  Kolkata Knight Riders
#
# [459523 rows x 29 columns]

# %%
teams=pd.concat([match_df['Team1'], match_df['Team2']])
n_teams=set(teams)
n_teams
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
match_df2.shape
# Out:
# (459523, 29)

# %%
#Grouping dataframe by "Season","BattingTeam" to get matches played by each team in each season
teams_df= match_df2.groupby(['Season', 'BattingTeam']).agg({"ID":"nunique"}).reset_index()

# %%
teams_df
# Out:
#     Season                  BattingTeam  ID
# 0     2008          Chennai Super Kings  16
# 1     2008              Deccan Chargers  14
# 2     2008               Delhi Capitals  14
# 3     2008        Kolkata Knight Riders  13
# 4     2008               Mumbai Indians  14
# ..     ...                          ...  ..
# 121   2022               Mumbai Indians  14
# 122   2022                 Punjab Kings  14
# 123   2022             Rajasthan Royals  17
# 124   2022  Royal Challengers Bangalore  16
# 125   2022          Sunrisers Hyderabad  14
#
# [126 rows x 3 columns]

# %%
#Grouping dataframe by "Season","WinningTeam" to get matches won by team in each season
teams_df1= match_df2.groupby(['Season', 'WinningTeam']).agg({"ID":"nunique"}).reset_index()

# %%
teams_df1
# Out:
#     Season                  WinningTeam  ID
# 0     2008          Chennai Super Kings   9
# 1     2008              Deccan Chargers   2
# 2     2008               Delhi Capitals   7
# 3     2008        Kolkata Knight Riders   6
# 4     2008               Mumbai Indians   7
# ..     ...                          ...  ..
# 121   2022               Mumbai Indians   4
# 122   2022                 Punjab Kings   7
# 123   2022             Rajasthan Royals  10
# 124   2022  Royal Challengers Bangalore   9
# 125   2022          Sunrisers Hyderabad   6
#
# [126 rows x 3 columns]

# %%
#Renaming columns
teams_df1.rename(columns={"WinningTeam":"Team","ID":"Win"},inplace=True)
teams_df.rename(columns={"BattingTeam":"Team","ID":"Matches_Played"},inplace=True)

# %%
teams_data=teams_df.merge(teams_df1,on=["Season","Team"])

# %%
teams_data
# Out:
#     Season                         Team  Matches_Played  Win
# 0     2008          Chennai Super Kings              16    9
# 1     2008              Deccan Chargers              14    2
# 2     2008               Delhi Capitals              14    7
# 3     2008        Kolkata Knight Riders              13    6
# 4     2008               Mumbai Indians              14    7
# ..     ...                          ...             ...  ...
# 121   2022               Mumbai Indians              14    4
# 122   2022                 Punjab Kings              14    7
# 123   2022             Rajasthan Royals              17   10
# 124   2022  Royal Challengers Bangalore              16    9
# 125   2022          Sunrisers Hyderabad              14    6
#
# [126 rows x 4 columns]

# %%
#Calculating matches lost
teams_data["Loss"]=teams_data["Matches_Played"]-teams_data["Win"]

# %%
teams_data
# Out:
#     Season                         Team  Matches_Played  Win  Loss
# 0     2008          Chennai Super Kings              16    9     7
# 1     2008              Deccan Chargers              14    2    12
# 2     2008               Delhi Capitals              14    7     7
# 3     2008        Kolkata Knight Riders              13    6     7
# 4     2008               Mumbai Indians              14    7     7
# ..     ...                          ...             ...  ...   ...
# 121   2022               Mumbai Indians              14    4    10
# 122   2022                 Punjab Kings              14    7     7
# 123   2022             Rajasthan Royals              17   10     7
# 124   2022  Royal Challengers Bangalore              16    9     7
# 125   2022          Sunrisers Hyderabad              14    6     8
#
# [126 rows x 5 columns]

# %%
teams_data[teams_data["Team"]=="Chennai Super Kings"].reset_index(drop=True)
# Out:
#    Season                 Team  Matches_Played  Win  Loss
# 0    2008  Chennai Super Kings              16    9     7
# 1    2009  Chennai Super Kings              14    8     6
# 2    2010  Chennai Super Kings              16    9     7
# 3    2011  Chennai Super Kings              16   11     5
# 4    2012  Chennai Super Kings              18   10     8
# 5    2013  Chennai Super Kings              18   12     6
# 6    2014  Chennai Super Kings              16   10     6
# 7    2015  Chennai Super Kings              17   10     7
# 8    2018  Chennai Super Kings              16   11     5
# 9    2019  Chennai Super Kings              17   10     7
# 10   2020  Chennai Super Kings              14    6     8
# 11   2021  Chennai Super Kings              16   11     5
# 12   2022  Chennai Super Kings              14    4    10

# %%
#teams_data.to_csv("teams_data.csv")

# %%
#Getting Trophy Winners Data
m=match_df2[match_df2["MatchNumber"]=="Final"]
trophy=m.groupby(["Season","WinningTeam"]).agg({"ID":"nunique"}).reset_index()

# %%
trophy
# Out:
#    Season            WinningTeam  ID
# 0    2008       Rajasthan Royals   1
# 1    2009        Deccan Chargers   1
# 2    2010    Chennai Super Kings   1
# 3    2011    Chennai Super Kings   1
# 4    2012  Kolkata Knight Riders   1
# 5    2013         Mumbai Indians   1
# 6    2014  Kolkata Knight Riders   1
# 7    2015         Mumbai Indians   1
# 8    2016    Sunrisers Hyderabad   1
# 9    2017         Mumbai Indians   1
# 10   2018    Chennai Super Kings   1
# 11   2019         Mumbai Indians   1
# 12   2020         Mumbai Indians   1
# 13   2021    Chennai Super Kings   1
# 14   2022         Gujarat Titans   1

# %%
#IPL runner Ups data
runners=match_df2[match_df2["BowlingTeam"]!=match_df2["WinningTeam"]]

# %%
r=runners[runners["MatchNumber"]=="Final"]
runner=r.groupby(["Season","BowlingTeam"]).agg({"ID":"nunique"}).reset_index()

# %%
runner
# Out:
#    Season                  BowlingTeam  ID
# 0    2008          Chennai Super Kings   1
# 1    2009  Royal Challengers Bangalore   1
# 2    2010               Mumbai Indians   1
# 3    2011  Royal Challengers Bangalore   1
# 4    2012          Chennai Super Kings   1
# 5    2013          Chennai Super Kings   1
# 6    2014                 Punjab Kings   1
# 7    2015          Chennai Super Kings   1
# 8    2016  Royal Challengers Bangalore   1
# 9    2017       Rising Pune Supergiant   1
# 10   2018          Sunrisers Hyderabad   1
# 11   2019          Chennai Super Kings   1
# 12   2020               Delhi Capitals   1
# 13   2021        Kolkata Knight Riders   1
# 14   2022             Rajasthan Royals   1

# %%
#Final dataset of IPL winners and runners
final_match=trophy.merge(runner,on=["Season"])

# %%
final_match.rename(columns={"WinningTeam":"Winner","BowlingTeam":"Runner"},inplace=True)
final_match.drop(columns=["ID_x","ID_y"],inplace=True)

# %%
final_match
# Out:
#    Season                 Winner                       Runner
# 0    2008       Rajasthan Royals          Chennai Super Kings
# 1    2009        Deccan Chargers  Royal Challengers Bangalore
# 2    2010    Chennai Super Kings               Mumbai Indians
# 3    2011    Chennai Super Kings  Royal Challengers Bangalore
# 4    2012  Kolkata Knight Riders          Chennai Super Kings
# 5    2013         Mumbai Indians          Chennai Super Kings
# 6    2014  Kolkata Knight Riders                 Punjab Kings
# 7    2015         Mumbai Indians          Chennai Super Kings
# 8    2016    Sunrisers Hyderabad  Royal Challengers Bangalore
# 9    2017         Mumbai Indians       Rising Pune Supergiant
# 10   2018    Chennai Super Kings          Sunrisers Hyderabad
# 11   2019         Mumbai Indians          Chennai Super Kings
# 12   2020         Mumbai Indians               Delhi Capitals
# 13   2021    Chennai Super Kings        Kolkata Knight Riders
# 14   2022         Gujarat Titans             Rajasthan Royals

# %%
#final_match.to_csv("final_match.csv")

# %%
#Data Visualization
team="Rajasthan Royals"
team_data=teams_data[teams_data["Team"]==team]
print("Total_matches_played:",team_data["Matches_Played"].sum())
print("Won:",team_data["Win"].sum())
print("Lost:",team_data["Loss"].sum())
tr=final_match[final_match["Winner"]==team]
print("IPL Tropies: ",len(tr))
ru=final_match[final_match["Runner"]==team]  
print("IPL Runner Up : ",len(ru))      
plt.figure(figsize=(10, 6))
plt.plot(team_data["Season"], team_data["Win"], marker='o', label='Wins', color='green')
plt.plot(team_data["Season"], team_data["Loss"], marker='o', label='Lost', color='red')
plt.plot(team_data["Season"], team_data["Matches_Played"], marker='o', label='Matches Played', color='blue')
plt.title('Chennai Super Kings Performance (2008-2022)')
plt.xlabel('Year')
plt.ylabel('Number of Matches')
plt.xticks(team_data["Season"], rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total_matches_played: 191
# Won: 96
# Lost: 95
# IPL Tropies:  1
# IPL Runner Up :  1

# %%
sns.countplot(data=final_match,y="Winner",order=final_match["Winner"].value_counts().index)
plt.title("Frequency of IPL Wins Finishes by Team")
plt.xlabel("Count")
plt.ylabel("Teams")
plt.show()

# %%
sns.countplot(data=final_match,y="Runner",order=final_match["Runner"].value_counts().index)
plt.title("Frequency of IPL Runner-up Finishes by Team")
plt.xlabel("Count")
plt.ylabel("Teams")
plt.show()
